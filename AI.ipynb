# %% [markdown]
# <a href="https://colab.research.google.com/github/abhitele07/Developement/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
uimport numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("/content/data.xlsx")

area = np.array([240,400,480,613,733,853,973,1093,1213])
price= np.array([169000,219000,253000,297666,339666,381666,423666,465666,507666,])

print (data)

# %%
area = np.array([240,400,480,613,733,853,973,1093,1213])
price= np.array([169000,219000,253000,297666,339666,381666,423666,465666,507666])
data={"area":area,"price":price}
df=pd.DataFrame(data=data)
print(data)

# %%
# %matplotlib inline
plt.scatter(df["area"],df["price"])
plt.show()

# %%
# %matplotlib inline
plt.scatter(data["area"],data["price"],color="red",marker="*")
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area vs Price")

plt.show()

# %%
model=LinearRegression()
new_df=df.drop("price",axis="columns")

new_df

# %%
model.fit(new_df,df.price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4949538f9ca7> in <module>
# ----> 1 model.fit(new_df,df.price)
#
# NameError: name 'model' is not defined

# %%
model.predict([[300]])

# %%
model.intercept_
model.coef_

# %%
predict2=(model.coef_)*300+(model.intercept_)

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("/content/House.xlsx")
print(data)

# %%
# %matplotlib inline
plt.scatter(data["Age"],data["Price"],color="green",marker="*")
plt.xlabel("Age")
plt.ylabel("Price")
plt.title("Age vs Price")

plt.show()

# %%
# %matplotlib inline
plt.scatter(data["No of bedroom"],data["Price"],color="red",marker="*")
plt.xlabel("No of bedroom")
plt.ylabel("Price")
plt.title("No of bedroom vs Price")

plt.show()

# %%
model=LinearRegression()

# %%
new_df = data.drop("Price",axis="columns")

# %%
model.fit(new_df,data.Price)
# Out:
# LinearRegression()

# %%
model.predict=([[240,3,2]])

# %%
model.coef_

# %%
model.intercept_
# Out:
# 254961.40270050208

# %%
#To find predicted value
predict2=(model.coef_)*240+(model.intercept_)
print(predict2)

# %%
model.coef_*240+model.coef_+model.coef_*3+model.intercept_

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("/content/salary_info.xlsx")
print(data)

# %%
# %matplotlib inline
plt.scatter(data["test_score"],data["interview_score"],color="green",marker="*")
plt.xlabel("test_score")
plt.ylabel("interview_score")
plt.title("test_score vs interview_score")

plt.show()

# %%
# %matplotlib inline
plt.scatter(data["experience"],data["salary"],color="red",marker="*")
plt.xlabel("exeperience")
plt.ylabel("salary")
plt.title("experience vs salary")

plt.show()

# %%
model=LinearRegression()

# %%
new_df = data.drop("salary",axis="columns")

# %%
model.fit(new_df,data.salary)

# %%
model.coef_
# Out:
# array([-23991.35767637,  59822.55022794,  59136.51010498])

# %%
model.intercept_
# Out:
# 394143.41505427426

# %%
model.coef_*7+model.coef_*9+model.intercept_*13
# Out:
# array([4740002.6728836 , 6081025.19935257, 6070048.55738532])

# %%
model.predict=([[7,9,7]])

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
data=pd.read_excel("/content/insurence.xlsx")
print(data)
# Out:
#     age  ins
# 0    28    0
# 1    22    0
# 2    54    1
# 3    18    0
# 4    20    0
# 5    70    1
# 6    45    0
# 7    65    1
# 8    50    1
# 9    32    0
# 10   44    1
# 11   25    1

# %%
# %matplotlib inline
plt.scatter(data["age"],data["ins"],color="green",marker="*")
plt.xlabel("agee")
plt.ylabel("ins")
plt.title("age vs ins")

plt.show()

# %%
model=LogisticRegression()

# %%
new_df = data.drop("ins",axis="columns")
print(new_df)
# Out:
#     age
# 0    28
# 1    22
# 2    54
# 3    18
# 4    20
# 5    70
# 6    45
# 7    65
# 8    50
# 9    32
# 10   44
# 11   25

# %%
model.fit(new_df,data.ins)
# Out:
# LogisticRegression()

# %%
model.intercept_
# Out:
# array([-4.90082565])

# %%
model.coef_
# Out:
# array([[0.1285343]])

# %%
model.predict([[54]])

# %%
model.predict_proba([[54]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[0.115064, 0.884936]])

# %%
model.predict_proba([[28]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([[0.78614871, 0.21385129]])

# %%
abhi = "Abhitherockstar"
abhi[6]
# Out:
# 'e'

# %%
abhi[2:7]
# Out:
# 'hithe'

# %%
abhi[0:11:5]
# Out:
# 'Ahk'

# %%
abhi[:6]
# Out:
# 'Abhith'

# %%
first_name= "Abhishek"
Favorite_in= "Coading"
print(f"hi i am {first_name}. i am good in {Favorite_in}.")
# Out:
# hi i am Abhishek. i am good in Coading.

# %%
value = 6
print(f"The value is {value} this is multiplied by 2 then ans is: {value * 2}")
# Out:
# The value is 6 this is multiplied by 2 then ans is: 12

# %%
print(f"{abhi.upper()}")

# %%
import pandas as pd

# %%
data=pd.read_excel("/content/age.xlsx")
data

# %%
data["age"].plot.box()

# %%
data=pd.read_excel("/content/age (1).xlsx")
data

# %%
data["age"].plot.box()

# %%
data["age"].quantile([0.75,0.97,0.99])
# Out:
# 0.75    54.5
# 0.97    69.5
# 0.99    70.0
# Name: age, dtype: float64

# %%
max_threshold=data["age"].quantile(0.99)
max_threshold
# Out:
# 70.0

# %%
data=data[data["age"]<max_threshold]
data

# %% [markdown]
# # Multivarient Logistic Regression

# %% [markdown]
# **Example:**
#
# Dataset = Digit
#
# library = sklearn

# %%
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt

# %%
digit = load_digits()
plt.matshow(digit.images[0])

# %%
a = digit.data[0]
b =a.reshape(8,8)
b
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(digit.data,digit.target,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
model.predict([digit.data[0]])
# Out:
# array([0])

# %%
model.predict([digit.data[1100]])
# Out:
# array([9])

# %%
c = digit.data[123]

# %%
d = c.reshape(8,8)
d
# Out:
# array([[ 0.,  0.,  5., 14., 15.,  4.,  0.,  0.],
#        [ 0.,  0.,  8., 16., 16., 14.,  0.,  0.],
#        [ 0.,  0.,  5., 16., 16.,  9.,  0.,  0.],
#        [ 0.,  0.,  0., 15., 16.,  1.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 13.,  0.,  0.,  0.],
#        [ 0.,  0., 11., 15., 14.,  5.,  0.,  0.],
#        [ 0.,  0., 12., 12.,  8., 15.,  1.,  0.],
#        [ 0.,  0.,  5., 16., 16., 16.,  2.,  0.]])

# %%
plt.matshow(digit.images[1100])

# %%
model.score(x_test,y_test)
# Out:
# 0.9694444444444444

# %%
from sklearn.metrics import confusion_matrix

# %%
prediction = model.predict(x_test)
con_metrics = confusion_matrix(y_test,prediction)
con_metrics

# %%
import seaborn as sb

# %%
plt.figure(figsize=(10,10))
sb.heatmap(con_metrics,annot=True)

# %% [markdown]
# # Unsupervised Learning
